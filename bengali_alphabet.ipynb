# %% [markdown]
# Let´s relearn the bengali alphabet

# %%
# !pip install gtts
# !pip install -U deep-translator

# %%
from googletrans import Translator  
from deep_translator import GoogleTranslator
from IPython.display import Audio  
import asyncio
import IPython.display as ipd

def translate_to_bengali(text):
    translated = GoogleTranslator(source='auto', target='bn').translate(text) 
    return translated

def bengali_tts(bengali_text):
    tts = gTTS(text=f'{bengali_text}', lang='bn')  
    tts.save("bengali_audio.mp3")  
    print(f"Bengali: {bengali_text}")  
    return Audio("bengali_audio.mp3", autoplay=True)  

def speak_bengali(text):
    bengali_text = translate_to_bengali(text)
    return bengali_tts(bengali_text)

speak_bengali("Hej")
# Out:
# Bengali: হ্যালো
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
speak_bengali("Hur mår du?")
# Out:
# Bengali: তুমি কেমন আছো?
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Now we ask a chatbot of our preferance to generate the bengali alphabet for us in list-of-strings format

# %% [markdown]
# Vowels:
#
# অ আ ই ঈ উ ঊ ঋ এ ঐ ও ঔ

# %%
bengali_vowels = ["অ", "আ", "ই", "ঈ", "উ", "ঊ", "ঋ", "এ", "ঐ", "ও", "ঔ"]

for char in bengali_vowels:
    ipd.display(speak_bengali(char))
# Out:
# Bengali: অ
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# Bengali: আ
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# Bengali: ই
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# Bengali: ঈ
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
# ...

# %% [markdown]
# Consonants:
#
# ক খ গ ঘ ঙ
# চ ছ জ ঝ ঞ
# ট ঠ ড ঢ ণ
# ত থ দ ধ ন
# প ফ ব ভ ম
# য র ল শ
# ষ স হ
# ক্ষ त्र ज्ञ

# %%
bengali_consonants = [
    "ক", "খ", "গ", "ঘ", "ঙ",
    "চ", "ছ", "জ", "ঝ", "ঞ",
    "ট", "ঠ", "ড", "ঢ", "ণ",
    "ত", "থ", "দ", "ধ", "ন",
    "প", "ফ", "ব", "ভ", "ম",
    "য", "র", "ল", "শ",
    "ষ", "স", "হ",
    "ক্ষ", "त्र", "ज्ञ"
]

for char in bengali_consonants:
    ipd.display(speak_bengali(char))
# Out:
# Bengali: ক
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# Bengali: খ
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# Bengali: গ
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# Bengali: ঘ
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
# ...
